# %%
import pandas as pd

# %%
df = pd.read_csv('dataframe_rectify_noun.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    end  satisfaction  something  observe   need  support  price  \
# 0           0  False         False      False    False  False    False  False
# 1           1  False         False      False    False  False     True  False
# 2           2  False         False      False    False   True    False  False
# 3           3  False         False      False    False  False    False   True
# 4           4  False         False       True    False  False    False   True
#
#    queen   week  ...  sturdy    ply  superb   want   game   kind  warranty  \
# 0  False  False  ...   False  False   False  False  False  False     False
# 1  False  False  ...   False  False   False  False  False  False     False
# 2  False  False  ...   False   True   False  False  False  False     False
# 3  False   True  ...   False  False   False  False  False  False     False
# 4  False  False  ...   False  False   False  False  False  False     False
#
#    frame  schedule  surface
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'end', 'satisfaction', 'something', 'observe', 'need',
#        'support', 'price', 'queen', 'week',
#        ...
#        'sturdy', 'ply', 'superb', 'want', 'game', 'kind', 'warranty', 'frame',
#        'schedule', 'surface'],
#       dtype='object', length=305)

# %%
df.drop(columns='Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#      end  satisfaction  something  observe   need  support  price  queen  \
# 0  False         False      False    False  False    False  False  False
# 1  False         False      False    False  False     True  False  False
# 2  False         False      False    False   True    False  False  False
# 3  False         False      False    False  False    False   True  False
# 4  False         False       True    False  False    False   True  False
#
#     week   void  ...  sturdy    ply  superb   want   game   kind  warranty  \
# 0  False  False  ...   False  False   False  False  False  False     False
# 1  False  False  ...   False  False   False  False  False  False     False
# 2  False  False  ...   False   True   False  False  False  False     False
# 3   True  False  ...   False  False   False  False  False  False     False
# 4  False  False  ...   False  False   False  False  False  False     False
#
#    frame  schedule  surface
# 0  False     False    False
# ...

# %%
df.values
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
fpgrowth(df, min_support=0.05, use_colnames=True)
# Out:
#      support                          itemsets
# 0   0.428287                            (good)
# 1   0.422709                         (product)
# 2   0.281275                    (installation)
# 3   0.167729                             (bed)
# 4   0.090837                          (design)
# 5   0.059363                           (thing)
# 6   0.056574                            (time)
# 7   0.053386                        (purchase)
# 8   0.119920                           (money)
# 9   0.075299                        (delivery)
# 10  0.057769                             (guy)
# 11  0.051793                        (mattress)
# 12  0.050598                           (shift)
# 13  0.078088                           (price)
# 14  0.094821                         (quality)
# 15  0.072510                         (service)
# 16  0.105578                             (buy)
# 17  0.096414                           (value)
# 18  0.074900                            (nice)
# ...

# %%
#df1 = apriori(df,min_support=0.01,use_colnames=True)
#df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a4e02f36abed> in <module>
# ----> 1 df1 = apriori(df,min_support=0.01,use_colnames=True)
#       2 df1
#
# NameError: name 'apriori' is not defined

# %%
#df1.sort_values(by="support",ascending=False)

# %%
#df1['length'] = df1['itemsets'].apply(lambda x:len(x))
#df1

# %%
#df1[(df1['length']==1) & (df1['support']>=0.001)]
